# %% [markdown]
# # Welcome!
# This notebook demonstrates how to develop a conversational system that uses a deep knowledge base about hotels, combining structured instance-level data and an ontological model. The knowledge graph (KG) and ontology enable reasoning to enhance dialogue response generation. The task involves integrating a GraphRAG-like approach to query the knowledge base and generate accurate, context-aware responses.
#
# Specifically, the notebook has the following steps:
#
# 1. **Setup**: Loading the knowledge graph, dialogues, and required libraries (e.g., OWLAPY).
# 2. **Analyzing the knowledge graph**: Exploring its structure and entities using OWLAPY queries.
# 3. **Extending the ontology**: Adding TBox information for expressive reasoning.
# 4. **Creating dialogues**: Create dialogues based on the examples. Write 5 simple dialogues and 5 more detailed ones to showcase different types of interactions.
# 5. **Combining ontology and KG data**: Deploying an OWL reasoner to perform class-expression queries.
# 6. **Query generation with LLMs**: Using an LLM (e.g., Llama3.2) to generate or assist in creating queries against the KG.
# 7. **Generating responses**: Summarizing retrieved data into dialogue responses using a KG-augmented RAG approach.
# 8. **Evaluation**: Assessing the system's performance using metrics like intersection-over-union scores.
#
# ## Assignment
# The goal of this assignment is to develop a logic-enhanced conversational system that retrieves and reasons over domain knowledge to assist in dialogue response generation. You will focus on both the technical aspects of KG+ontology reasoning and the integration with LLMs for robust responses.
#
# ### Assignment Steps
# 1. **Analyze the provided knowledge graph and dialogues**:
#    - Explore the KG's entities, properties, and relevance to the dialogues.
#    - Identify opportunities where ontology reasoning enhances dialogue responses.
# 2. **Extend the ontology**:
#    - Add expressive TBox information to support meaningful inferences.
# 3. **Deploy the reasoning environment**:
#    - Use OWLAPY to combine the KG (as ABox) with the ontology for reasoning-based queries.
# 4. **Generate class-expression queries**:
#    - Use instruction-based, few-shot prompting with Llama3.2 to produce or assist in creating the queries.
# 5. **Summarize results into dialogue responses**:
#    - Apply KG-augmented RAG to generate user-facing answers based on reasoning results.
# 6. **Evaluate the system**:
#    - Use appropriate metrics, including intersection-over-union scores for set-based answers.
#
# ## Report
# Write a **5-page report** in LNCS format that includes:
#
# 1. **Introduction**: Background on conversational systems with LLMs and the role of reasoning over domain knowledge.
# 2. **Methodology**: A detailed description of your approach, including diagrams and examples.
# 3. **Results**: Evaluation findings from the implemented steps.
# 4. **Discussion**: Strengths and weaknesses of your approach, lessons learned, and potential improvements.
#
# Make sure to use the following template: [Springer Lecture Notes in Computer Science](https://www.overleaf.com/latex/templates/springer-lecture-notes-in-computer-science/kzwwpvhwnvfj)
#
#
# ## Grading
# Your work will be evaluated based on:
#
# 1. **Code Implementation (30%)**: Quality and functionality of the logic-enhanced conversational system.
# 2. **Report (70%)**: Depth of analysis and clarity in presenting methods, results, and lessons learned.
#
# ## Kaggle Environment Notes
# To ensure smooth execution:
# - Load the required data into `/kaggle/input/`.
# - Use `/kaggle/working/` for saving temporary files.
# - Turn on GPUs and internet connectivity when necessary, and follow best practices for resource management.

# %% [markdown]
# ##### For colab: setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##### For colab pip installs + ollama installation

# %%
# !sudo apt-get update && sudo apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh

# !pip install ollama parsimonious rdflib SPARQLWrapper owlapy
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [345 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,297 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,604 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,205 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,411 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,637 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,968 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,600 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Get:24 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,867 kB]
# Fetched 38.5 MB in 5s (8,118 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 90 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 1s (475 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package zstd.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Collecting ollama
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting parsimonious
#   Downloading parsimonious-0.11.0-py3-none-any.whl.metadata (26 kB)
# Collecting rdflib
#   Downloading rdflib-7.5.0-py3-none-any.whl.metadata (12 kB)
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting owlapy
#   Downloading owlapy-1.6.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.12/dist-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.12/dist-packages (from ollama) (2.12.3)
# Requirement already satisfied: regex>=2022.3.15 in /usr/local/lib/python3.12/dist-packages (from parsimonious) (2025.11.3)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from rdflib) (3.3.1)
# Requirement already satisfied: scikit-learn>=1.5.2 in /usr/local/lib/python3.12/dist-packages (from owlapy) (1.6.1)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from owlapy) (2.2.2)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from owlapy) (2.32.4)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from owlapy) (2.4.0)
# Collecting owlready2>=0.40 (from owlapy)
#   Downloading owlready2-0.49.tar.gz (27.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 58.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting JPype1>=1.5.0 (from owlapy)
#   Downloading jpype1-1.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: tqdm>=4.66.5 in /usr/local/lib/python3.12/dist-packages (from owlapy) (4.67.1)
# Requirement already satisfied: fastapi>=0.115.5 in /usr/local/lib/python3.12/dist-packages (from owlapy) (0.123.10)
# Requirement already satisfied: uvicorn>=0.32.1 in /usr/local/lib/python3.12/dist-packages (from owlapy) (0.40.0)
# Collecting dicee==0.2.0 (from owlapy)
#   Downloading dicee-0.2.0-py3-none-any.whl.metadata (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 6.7 MB/s eta 0:00:00
# Collecting litserve>=0.2.0 (from owlapy)
#   Downloading litserve-0.2.17-py3-none-any.whl.metadata (24 kB)
# Collecting dspy==3.0.3 (from owlapy)
#   Downloading dspy-3.0.3-py3-none-any.whl.metadata (7.2 kB)
# Collecting polars==1.9.0 (from dicee==0.2.0->owlapy)
#   Downloading polars-1.9.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: pyarrow>=11.0.0 in /usr/local/lib/python3.12/dist-packages (from dicee==0.2.0->owlapy) (18.1.0)
# Requirement already satisfied: torch>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from dicee==0.2.0->owlapy) (2.9.0+cu126)
# Collecting lightning>=2.1.3 (from dicee==0.2.0->owlapy)
#   Downloading lightning-2.6.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: tiktoken>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from dicee==0.2.0->owlapy) (0.12.0)
# Requirement already satisfied: psutil>=5.9.4 in /usr/local/lib/python3.12/dist-packages (from dicee==0.2.0->owlapy) (5.9.5)
# Requirement already satisfied: matplotlib>=3.8.2 in /usr/local/lib/python3.12/dist-packages (from dicee==0.2.0->owlapy) (3.10.0)
# Collecting pykeen>=1.10.2 (from dicee==0.2.0->owlapy)
#   Downloading pykeen-1.11.1-py3-none-any.whl.metadata (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 8.9 MB/s eta 0:00:00
# Collecting numpy==1.26.4 (from dicee==0.2.0->owlapy)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.9 MB/s eta 0:00:00
# Collecting backoff>=2.2 (from dspy==3.0.3->owlapy)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: joblib~=1.3 in /usr/local/lib/python3.12/dist-packages (from dspy==3.0.3->owlapy) (1.5.3)
# Requirement already satisfied: openai>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from dspy==3.0.3->owlapy) (2.14.0)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from dspy==3.0.3->owlapy) (3.11.5)
# Collecting optuna>=3.4.0 (from dspy==3.0.3->owlapy)
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Collecting magicattr>=0.1.6 (from dspy==3.0.3->owlapy)
#   Downloading magicattr-0.1.6-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting litellm>=1.64.0 (from dspy==3.0.3->owlapy)
#   Downloading litellm-1.80.16-py3-none-any.whl.metadata (29 kB)
# Collecting diskcache>=5.6.0 (from dspy==3.0.3->owlapy)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting json-repair>=0.30.0 (from dspy==3.0.3->owlapy)
#   Downloading json_repair-0.55.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from dspy==3.0.3->owlapy) (9.1.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from dspy==3.0.3->owlapy) (4.12.1)
# Collecting asyncer==0.0.8 (from dspy==3.0.3->owlapy)
#   Downloading asyncer-0.0.8-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy==3.0.3->owlapy) (6.2.4)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dspy==3.0.3->owlapy) (3.1.2)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from dspy==3.0.3->owlapy) (13.9.4)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy==3.0.3->owlapy) (3.6.0)
# Collecting gepa==0.0.7 (from gepa[dspy]==0.0.7->dspy==3.0.3->owlapy)
#   Downloading gepa-0.0.7-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.5->owlapy) (0.50.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.5->owlapy) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.5->owlapy) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from JPype1>=1.5.0->owlapy) (25.0)
# Requirement already satisfied: pyzmq>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from litserve>=0.2.0->owlapy) (26.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->owlapy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->owlapy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->owlapy) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->owlapy) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->owlapy) (2.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.5.2->owlapy) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.5.2->owlapy) (3.6.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.32.1->owlapy) (8.3.1)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.1.3->dicee==0.2.0->owlapy) (6.0.3)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.1.3->dicee==0.2.0->owlapy) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.1.3->dicee==0.2.0->owlapy)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting torchmetrics<3.0,>0.7.0 (from lightning>=2.1.3->dicee==0.2.0->owlapy)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Collecting pytorch-lightning (from lightning>=2.1.3->dicee==0.2.0->owlapy)
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy==3.0.3->owlapy) (3.13.3)
# Collecting fastuuid>=0.13.0 (from litellm>=1.64.0->dspy==3.0.3->owlapy)
#   Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: grpcio!=1.68.*,!=1.69.*,!=1.70.*,!=1.71.0,!=1.71.1,!=1.72.0,!=1.72.1,!=1.73.0,>=1.62.3 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy==3.0.3->owlapy) (1.76.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy==3.0.3->owlapy) (8.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy==3.0.3->owlapy) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy==3.0.3->owlapy) (4.26.0)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy==3.0.3->owlapy) (1.2.1)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy==3.0.3->owlapy) (0.22.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->dicee==0.2.0->owlapy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->dicee==0.2.0->owlapy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->dicee==0.2.0->owlapy) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->dicee==0.2.0->owlapy) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->dicee==0.2.0->owlapy) (11.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy==3.0.3->owlapy) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy==3.0.3->owlapy) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy==3.0.3->owlapy) (1.3.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy==3.0.3->owlapy) (1.17.2)
# Collecting colorlog (from optuna>=3.4.0->dspy==3.0.3->owlapy)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.4.0->dspy==3.0.3->owlapy) (2.0.45)
# Collecting dataclasses-json (from pykeen>=1.10.2->dicee==0.2.0->owlapy)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting click_default_group (from pykeen>=1.10.2->dicee==0.2.0->owlapy)
#   Downloading click_default_group-1.2.4-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from pykeen>=1.10.2->dicee==0.2.0->owlapy) (0.9.0)
# Collecting more_click (from pykeen>=1.10.2->dicee==0.2.0->owlapy)
#   Downloading more_click-0.1.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from pykeen>=1.10.2->dicee==0.2.0->owlapy) (10.8.0)
# Collecting pystow>=0.4.3 (from pykeen>=1.10.2->dicee==0.2.0->owlapy)
#   Downloading pystow-0.7.15-py3-none-any.whl.metadata (17 kB)
# Collecting docdata>=0.0.5 (from pykeen>=1.10.2->dicee==0.2.0->owlapy)
#   Downloading docdata-0.0.5-py3-none-any.whl.metadata (13 kB)
# Collecting class_resolver>=0.6.0 (from pykeen>=1.10.2->dicee==0.2.0->owlapy)
#   Downloading class_resolver-0.7.1-py3-none-any.whl.metadata (19 kB)
# Collecting torch_max_mem>=0.1.4 (from pykeen>=1.10.2->dicee==0.2.0->owlapy)
#   Downloading torch_max_mem-0.1.4-py3-none-any.whl.metadata (12 kB)
# Collecting torch-ppr>=0.0.7 (from pykeen>=1.10.2->dicee==0.2.0->owlapy)
#   Downloading torch_ppr-0.0.8-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->owlapy) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy==3.0.3->owlapy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->dspy==3.0.3->owlapy) (2.19.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (3.20.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (3.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.5.1->dicee==0.2.0->owlapy) (3.5.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.29.0->litserve>=0.2.0->owlapy) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.29.0->litserve>=0.2.0->owlapy) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.29.0->litserve>=0.2.0->owlapy) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.29.0->litserve>=0.2.0->owlapy) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy==3.0.3->owlapy) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy==3.0.3->owlapy) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy==3.0.3->owlapy) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy==3.0.3->owlapy) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy==3.0.3->owlapy) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy==3.0.3->owlapy) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy==3.0.3->owlapy) (1.22.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.4.0->dspy==3.0.3->owlapy) (1.3.10)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.64.0->dspy==3.0.3->owlapy) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.64.0->dspy==3.0.3->owlapy) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy==3.0.3->owlapy) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy==3.0.3->owlapy) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.23.0->litellm>=1.64.0->dspy==3.0.3->owlapy) (0.30.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->dspy==3.0.3->owlapy) (0.1.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.4.0->dspy==3.0.3->owlapy) (3.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.5.1->dicee==0.2.0->owlapy) (1.3.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->pykeen>=1.10.2->dicee==0.2.0->owlapy)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->pykeen>=1.10.2->dicee==0.2.0->owlapy)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm>=1.64.0->dspy==3.0.3->owlapy) (0.36.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy==3.0.3->owlapy) (1.2.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen>=1.10.2->dicee==0.2.0->owlapy)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Downloading parsimonious-0.11.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 6.2 MB/s eta 0:00:00
# Downloading rdflib-7.5.0-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.2/587.2 kB 54.5 MB/s eta 0:00:00
# Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Downloading owlapy-1.6.2-py3-none-any.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 63.9 MB/s eta 0:00:00
# Downloading dicee-0.2.0-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 16.9 MB/s eta 0:00:00
# Downloading dspy-3.0.3-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 27.9 MB/s eta 0:00:00
# Downloading asyncer-0.0.8-py3-none-any.whl (9.2 kB)
# Downloading gepa-0.0.7-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 6.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 101.4 MB/s eta 0:00:00
# Downloading polars-1.9.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 24.6 MB/s eta 0:00:00
# Downloading jpype1-1.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (495 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.9/495.9 kB 47.3 MB/s eta 0:00:00
# Downloading litserve-0.2.17-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.5/94.5 kB 10.9 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.8 MB/s eta 0:00:00
# Downloading json_repair-0.55.0-py3-none-any.whl (29 kB)
# Downloading lightning-2.6.0-py3-none-any.whl (845 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 71.1 MB/s eta 0:00:00
# Downloading litellm-1.80.16-py3-none-any.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 131.6 MB/s eta 0:00:00
# Downloading magicattr-0.1.6-py2.py3-none-any.whl (4.7 kB)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 30.3 MB/s eta 0:00:00
# Downloading pykeen-1.11.1-py3-none-any.whl (730 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.3/730.3 kB 64.3 MB/s eta 0:00:00
# Downloading class_resolver-0.7.1-py3-none-any.whl (31 kB)
# Downloading docdata-0.0.5-py3-none-any.whl (9.2 kB)
# Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 13.0 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading pystow-0.7.15-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 4.0 MB/s eta 0:00:00
# Downloading torch_max_mem-0.1.4-py3-none-any.whl (13 kB)
# Downloading torch_ppr-0.0.8-py3-none-any.whl (12 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 80.2 MB/s eta 0:00:00
# Downloading click_default_group-1.2.4-py2.py3-none-any.whl (4.1 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading more_click-0.1.3-py3-none-any.whl (12 kB)
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 75.7 MB/s eta 0:00:00
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 5.7 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: owlready2
#   Building wheel for owlready2 (pyproject.toml) ... done
#   Created wheel for owlready2: filename=owlready2-0.49-py3-none-any.whl size=23742426 sha256=bf3d249871578462dc87108ca8958a8a665e3c82d1e05414a41999aab2fa0098
#   Stored in directory: /root/.cache/pip/wheels/43/fe/dc/a0de3c289cfd5923ece6524469d328950e14fa0c90b1088ffa
# Successfully built owlready2
# Installing collected packages: magicattr, rdflib, polars, parsimonious, owlready2, numpy, mypy-extensions, more_click, marshmallow, lightning-utilities, json-repair, JPype1, gepa, fastuuid, docdata, diskcache, colorlog, click_default_group, class_resolver, backoff, typing-inspect, SPARQLWrapper, pystow, asyncer, optuna, ollama, dataclasses-json, torchmetrics, torch_max_mem, litserve, litellm, torch-ppr, pytorch-lightning, dspy, pykeen, lightning, dicee, owlapy
#   Attempting uninstall: polars
#     Found existing installation: polars 1.31.0
#     Uninstalling polars-1.31.0:
#       Successfully uninstalled polars-1.31.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytensor 2.36.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# cudf-polars-cu12 25.10.0 requires polars<1.33,>=1.28, but you have polars 1.9.0 which is incompatible.
# Successfully installed JPype1-1.6.0 SPARQLWrapper-2.0.0 asyncer-0.0.8 backoff-2.2.1 class_resolver-0.7.1 click_default_group-1.2.4 colorlog-6.10.1 dataclasses-json-0.6.7 dicee-0.2.0 diskcache-5.6.3 docdata-0.0.5 dspy-3.0.3 fastuuid-0.14.0 gepa-0.0.7 json-repair-0.55.0 lightning-2.6.0 lightning-utilities-0.15.2 litellm-1.80.16 litserve-0.2.17 magicattr-0.1.6 marshmallow-3.26.2 more_click-0.1.3 mypy-extensions-1.1.0 numpy-1.26.4 ollama-0.6.1 optuna-4.6.0 owlapy-1.6.2 owlready2-0.49 parsimonious-0.11.0 polars-1.9.0 pykeen-1.11.1 pystow-0.7.15 pytorch-lightning-2.6.0 rdflib-7.5.0 torch-ppr-0.0.8 torch_max_mem-0.1.4 torchmetrics-1.8.2 typing-inspect-0.9.0

# %%
import subprocess
import time

subprocess.Popen(['ollama', 'serve'])

time.sleep(5)

# %% [markdown]
# # Import libraries

# %% [markdown]
# ##### All the imports + local graph init + ollama

# %% [markdown]
# ##### For colab setup

# %%
import os
import re
import ollama # this is sufficient if local
from owlready2 import *
from owlready2 import World
from parsimonious.exceptions import IncompleteParseError
from rdflib import Graph, Literal, Namespace, URIRef, RDF, RDFS
from rdflib import RDF, RDFS, OWL
from SPARQLWrapper import JSON, SPARQLWrapper

from owlapy import dl_to_owl_expression, manchester_to_owl_expression
from owlapy.class_expression import (
    OWLClass,
    OWLObjectHasValue,
    OWLObjectIntersectionOf,
    OWLObjectSomeValuesFrom
)
from owlapy.iri import IRI
from owlapy.owl_axiom import OWLObjectPropertyAssertionAxiom, OWLSubObjectPropertyOfAxiom
from owlapy.owl_individual import OWLNamedIndividual
from owlapy.owl_ontology import Ontology
from owlapy.owl_property import OWLObjectProperty
from owlapy.owl_reasoner import StructuralReasoner, SyncReasoner
# Out:
# c:\Users\hippo\miniconda3\envs\FLAI\Lib\site-packages\owlapy\static_funcs.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# for Colab RUN THIS WHEN USING OLLAMA IN COLAB (might need to run more than once,
# locally you need just pull llama3.2 once

#TODO: UNCOMMENT below for colab
# subprocess.Popen(["ollama", "serve"])
# time.sleep(10)

# !ollama pull llama3.2 # get the llama model 3.2

# %% [markdown]
# ### IMPORTANT: set to colab or local

# %%
# just use the extended_data relative path for local use
working_dir = "/content/drive/MyDrive/psai"
colab = False # HERE YOU CAN SET TO COLAB PATHS with True
if not colab:
    working_dir = ""
ttl_file_path = os.path.join(working_dir, "extended_data.ttl")
owl_file_path = os.path.join(working_dir, "extended_data.owl")

# might need to run this again if reasoning cannot find the graph
graph = Graph()
graph.parse(ttl_file_path, format="turtle")
# Out:
# <Graph identifier=N8e9137439b864d6fb1115fd0f50ab9b1 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # ~~ 1. Analyze the provided knowledge graph (data.ttl).~~

# %% [markdown]
# ### Don't run section 1 code, only output is needed here

# %%
## the provided knowledge graph is in turtle (.ttl) format, which owlready2 has trouble
## parsing correctly in this environment. to avoid this issue, we first load the file
## using rdflib (which fully supports turtle), convert it to n-triples,
## and then load the converted graph into owlready2 for analysis.
## for the record owlready2 is an inner library used by owlapy.

# src = "/kaggle/input/w1-dataset3/extended_data.ttl"
# dst = "/kaggle/working/data.nt"   ## .nt is the file format for n-triples
g = Graph()
g.parse("extended_data.ttl", format="turtle")   ## here we parse the .ttl
g.serialize("extended_data.nt", format="nt")   # here its converted into .nt

analysis_world = World()
analysis_onto = analysis_world.get_ontology(f"file://extended_data.nt").load(format="ntriples")

print("loaded into:", analysis_onto.base_iri)

# %%
from collections import Counter
from rdflib import URIRef, Literal
import pandas as pd

# helper funcs
def is_uri(x):
    return isinstance(x, URIRef)

def is_lit(x):
    return isinstance(x, Literal)

def shorten(term, graph):
    # compact display using namespaces when possible

    if isinstance(term, URIRef):
        try:
            return term.n3(graph.namespace_manager)
        except Exception:
            return str(term)
    if isinstance(term, Literal):
        if term.language:
            return f"\"{str(term)[:60]}\"@{term.language}"
        if term.datatype:
            return f"\"{str(term)[:60]}\"^^{term.datatype}"
        return f"\"{str(term)[:60]}\""
    return str(term)


triples = list(g.triples((None, None, None)))
print("--- basic info ---")
print("triples:", len(triples))

subjects = set(s for s, p, o in triples)
predicates = set(p for s, p, o in triples)
objects = set(o for s, p, o in triples)

uris = set(x for x in subjects.union(objects) if is_uri(x))
lits = set(x for x in objects if is_lit(x))

print("unique subjects:", len(subjects))
print("unique predicates:", len(predicates))
print("unique objects:", len(objects))
print("unique URI nodes (subjects U objects):", len(uris))
print("unique literal nodes (objects):", len(lits))

pred_counts = Counter(p for s, p, o in triples)
top_preds = pred_counts.most_common(30)

print()
print("--- top predicates (by triple count) ---")

df_preds = pd.DataFrame(
    [(str(p), shorten(p, g), c) for p, c in pred_counts.most_common()],
    columns=["predicate_iri", "predicate", "count"]
)
display(df_preds.head(30))

RDF_TYPE = URIRef("http://www.w3.org/1999/02/22-rdf-syntax-ns#type")

type_triples = list(g.triples((None, RDF_TYPE, None)))
class_counts = Counter(o for s, p, o in type_triples if is_uri(o))

print()
print("--- types / classes (rdf:type) ---")
print("rdf:type triples:", len(type_triples))
print("distinct classes:", len(class_counts))

df_classes = pd.DataFrame(
    [(str(cls), shorten(cls, g), c) for cls, c in class_counts.most_common()],
    columns=["class_iri", "class", "instances_count"]
)
display(df_classes.head(30))

datatype_counts = Counter()
lang_counts = Counter()
lit_pred_counts = Counter()
lit_lengths = []

for s, p, o in triples:
    if is_lit(o):
        lit_pred_counts[p] += 1
        if o.datatype:
            datatype_counts[o.datatype] += 1
        else:
            datatype_counts[None] += 1
        if o.language:
            lang_counts[o.language] += 1
        lit_lengths.append(len(str(o)))

print()
print("--- literals ---")
print("literal objects:", sum(lit_pred_counts.values()))
print("predicates with literals:", len(lit_pred_counts))
print("avg literal length:", (sum(lit_lengths) / len(lit_lengths)) if lit_lengths else 0)

print("top literal predicates:")
for p, c in lit_pred_counts.most_common(20):
    print(f"{c:>7}  {shorten(p, g)}")

print("top datatypes:")
for dt, c in datatype_counts.most_common(15):
    dt_name = "no-datatype" if dt is None else shorten(dt, g)
    print(f"{c:>7}  {dt_name}")

print("top languages:")
for lang, c in lang_counts.most_common(10):
    print(f"{c:>7}  {lang}")

df_lit_preds = pd.DataFrame(
    [(str(p), shorten(p, g), c) for p, c in lit_pred_counts.most_common()],
    columns=["predicate_iri", "predicate", "literal_count"]
)
display(df_lit_preds.head(30))
# Out:
# --- basic info ---
# triples: 9237
# unique subjects: 1789
# unique predicates: 14
# unique objects: 870
# unique URI nodes (subjects U objects): 1792
# unique literal nodes (objects): 476
#
# --- top predicates (by triple count) ---
#                                         predicate_iri           predicate  \
# 0     http://www.w3.org/1999/02/22-rdf-syntax-ns#type            rdf:type
# 1   http://kai.cs.vu.nl/2024/situated-minor-projec...     ns1:hasFacility
# 2   http://kai.cs.vu.nl/2024/situated-minor-projec...        ns1:location
# 3   http://kai.cs.vu.nl/2024/situated-minor-projec...      ns1:userRating
# 4          http://www.w3.org/2000/01/rdf-schema#label          rdfs:label
# 5   http://kai.cs.vu.nl/2024/situated-minor-projec...     ns1:nationality
# 6   http://kai.cs.vu.nl/2024/situated-minor-projec...  ns1:restaurantType
# 7   http://kai.cs.vu.nl/2024/situated-minor-projec...          ns1:inCity
# 8   http://kai.cs.vu.nl/2024/situated-minor-projec...            ns1:diet
# 9   http://kai.cs.vu.nl/2024/situated-minor-projec...          ns1:nextTo
# 10  http://kai.cs.vu.nl/2024/situated-minor-projec...       ns1:inCountry
# 11    http://www.w3.org/2000/01/rdf-schema#subClassOf     rdfs:subClassOf
# 12         http://www.w3.org/2000/01/rdf-schema#range          rdfs:range
# 13        http://www.w3.org/2000/01/rdf-schema#domain         rdfs:domain
#
#     count
# 0    3751
# 1    1640
# 2    1085
# 3    1000
# 4     485
# 5     472
# 6     305
# 7     267
# 8     137
# 9      34
# 10     34
# 11     18
# 12      7
# 13      2
# --- types / classes (rdf:type) ---
# rdf:type triples: 3751
# distinct classes: 32
#                                             class_iri  \
# 0       http://www.w3.org/2002/07/owl#NamedIndividual
# 1   http://kai.cs.vu.nl/2024/situated-minor-projec...
# 2   http://kai.cs.vu.nl/2024/situated-minor-projec...
# 3   http://kai.cs.vu.nl/2024/situated-minor-projec...
# 4   http://kai.cs.vu.nl/2024/situated-minor-projec...
# 5   http://kai.cs.vu.nl/2024/situated-minor-projec...
# 6   http://kai.cs.vu.nl/2024/situated-minor-projec...
# 7   http://kai.cs.vu.nl/2024/situated-minor-projec...
# 8                 http://www.w3.org/2002/07/owl#Class
# 9   http://kai.cs.vu.nl/2024/situated-minor-projec...
# 10               http://www.wikidata.org/entity/Q4022
# 11  http://kai.cs.vu.nl/2024/situated-minor-projec...
# 12       http://www.w3.org/2002/07/owl#ObjectProperty
# 13  http://kai.cs.vu.nl/2024/situated-minor-projec...
# 14  http://kai.cs.vu.nl/2024/situated-minor-projec...
# 15  http://kai.cs.vu.nl/2024/situated-minor-projec...
# 16  http://kai.cs.vu.nl/2024/situated-minor-projec...
# 17             http://www.wikidata.org/entity/Q573344
# 18  http://kai.cs.vu.nl/2024/situated-minor-projec...
# 19  http://kai.cs.vu.nl/2024/situated-minor-projec...
# 20                http://www.wikidata.org/entity/Q165
# 21             http://www.wikidata.org/entity/Q166620
# 22              http://www.wikidata.org/entity/Q12284
# 23          http://www.wikidata.org/entity/Q125941113
# 24            http://www.wikidata.org/entity/Q1973404
# 25              http://www.wikidata.org/entity/Q39594
# 26             http://www.w3.org/2002/07/owl#Ontology
# 27            http://www.wikidata.org/entity/Q1322134
# 28             http://www.wikidata.org/entity/Q355304
# 29             http://www.wikidata.org/entity/Q986177
#
#                                           class  instances_count
# 0                           owl:NamedIndividual             1746
# 1                                ns1:Restaurant              506
# 2                                     ns1:Hotel              344
# 3                              ns1:Camping_Site              342
# 4                                    ns1:Hostel              314
# 5                             ns1:Neighbourhood              267
# 6                                    ns1:Museum               55
# 7                                      ns1:City               34
# 8                                     owl:Class               33
# 9                              ns1:Trainstation               22
# 10       <http://www.wikidata.org/entity/Q4022>               12
# 11                              ns1:Nationality               10
# 12                           owl:ObjectProperty                9
# 13                                 ns1:Facility                8
# 14                        ns1:TouristAttraction                8
# 15                           ns1:RestaurantType                5
# 16                               ns1:UserRating                5
# 17     <http://www.wikidata.org/entity/Q573344>                5
# 18                                  ns1:Country                5
# 19                                     ns1:Diet                3
# 20        <http://www.wikidata.org/entity/Q165>                2
# 21     <http://www.wikidata.org/entity/Q166620>                2
# 22      <http://www.wikidata.org/entity/Q12284>                2
# 23  <http://www.wikidata.org/entity/Q125941113>                2
# 24    <http://www.wikidata.org/entity/Q1973404>                2
# 25      <http://www.wikidata.org/entity/Q39594>                2
# 26                                 owl:Ontology                1
# 27    <http://www.wikidata.org/entity/Q1322134>                1
# 28     <http://www.wikidata.org/entity/Q355304>                1
# 29     <http://www.wikidata.org/entity/Q986177>                1
# --- literals ---
# literal objects: 485
# predicates with literals: 1
# avg literal length: 13.393814432989691
# top literal predicates:
#     485  rdfs:label
# top datatypes:
#     485  no-datatype
# top languages:
#                                 predicate_iri   predicate  literal_count
# 0  http://www.w3.org/2000/01/rdf-schema#label  rdfs:label            485

# %% [markdown]
# # 2. Create a small ontology that can support expressive inference about hotels and analyse the dialogues (examples.txt).

# %% [markdown]
# ##### Convert ttl to owl
# (when making changes to ontology via ttl, use this to convert to owl for further usage in the notebook)

# %%
# file_name = "extended_data" # Change to your filename (without extension)
# g = Graph().parse(f"{file_name}.ttl", format="turtle")
# g.serialize(destination=f"{file_name}.owl", format="xml")

# %% [markdown]
# ##### Helper functions

# %%
def get_local_uri(label_text: str, file_path:str=owl_file_path) -> URIRef | None:
    """
    Converts wdt label to uri: eg Gulf to Q1322134.
    To ensure we can handle multiple name spaces. With owlapy manchester to owl, the issue
    is that it only takes one namespace as input. As we use ns1: and wdt: for our instances + classes
    + object properties this function is needed to replace with URIs
    """
    q = """
    SELECT ?s WHERE {
        # ?s ?p ?label .
        FILTER(STR(?label) = "%s")
    } LIMIT 1
    """ % label_text

    results = graph.query(q)
    for row in results:
        return row.s
    return None

uri = get_local_uri("Gulf") # test
print(uri)
# Out:
# http://www.wikidata.org/entity/Q1322134

# %%
def resolve_manchester_fillers(query: str) -> str:
    """
    Takes as input a query, then uses previous function along with re lib
    to swap all wdt instances / classes in a query to the correct URIs (only for wdt).
    The output query can almost be used to convert to OWL class expression.
    """
    keywords = {'and', 'or', 'some', 'only', 'value', 'min', 'max', 'exactly', 'not', 'that'}

    def replacement_logic(match):
        word = match.group(0)

        if word.lower() in keywords:
            return word

        uri = get_local_uri(word)

        if uri:
            uri_str = str(uri)
            if "wikidata.org" in uri_str:
                return uri_str #uri_str.split('/')[-1]

        return word

    return re.sub(r'\b\w+\b', replacement_logic, query)
_NS1 = Namespace("http://kai.cs.vu.nl/2024/situated-minor-project/hotel#")

def parse_and_fix_manchester(query: str) -> str:
    pattern = r"(\w+)\s+(some|value)\s+([^\s()]+)"

    def replacement(match):
        prop = match.group(1)
        target = match.group(3).strip()
        # print(target)
        if target.startswith("http"):
            target_uri = URIRef(target)
        else:
            target_uri = _NS1[target]

        is_individual = (target_uri, RDF.type, OWL.NamedIndividual) in graph
        # print(target_uri, is_individual)
        new_op = "value" if is_individual else "some"
        return f"{prop} {new_op} {target}"

    return re.sub(pattern, replacement, query)
# test

# query = "Hotel and (inCountry value Italy) and (nextTo some BodyOfWater) and (inCity value Rome)"
# x = resolve_manchester_fillers(query)
# print(resolve_manchester_fillers(query))

# %%
NS1 = "http://kai.cs.vu.nl/2024/situated-minor-project/hotel#"

def get_iri(identifier: str) -> IRI:
    # Strip any remaining parentheses from the start or end of the string
    identifier = identifier.strip("()")
    if identifier.startswith("http"):
        return IRI.create(identifier)
    return IRI(NS1, identifier)

def parse_manchester_query(query_str: str) -> OWLObjectSomeValuesFrom | OWLObjectHasValue | OWLObjectIntersectionOf:
    """
    Parser that converts some manchester query to one of:
    OWLObjectSomeValuesFrom | OWLObjectHasValue | OWLObjectIntersectionOf.
    Handles n conjuncts >= 0.
    Lacks OR and NOT operators (TBD if will be added).
    """

    parts = re.split(r'\s+and\s+', query_str)
    expressions = []

    for part in parts:
        part = part.strip().strip("()")

        if " some " in part:
            prop_str, filler_str = part.split(" some ")
            prop = OWLObjectProperty(get_iri(prop_str))
            filler = OWLClass(get_iri(filler_str))
            expressions.append(OWLObjectSomeValuesFrom(property=prop, filler=filler))

        elif " value " in part:
            prop_str, filler_str = part.split(" value ")
            prop = OWLObjectProperty(get_iri(prop_str))
            filler = OWLNamedIndividual(get_iri(filler_str))
            # Fixed: parameter name is 'value', not 'individual'
            expressions.append(OWLObjectHasValue(property=prop, individual=filler))

        else:
            expressions.append(OWLClass(get_iri(part)))

    # If there is only one expression, return it directly instead of an IntersectionOf
    if len(expressions) == 1:
        return expressions[0]

    return OWLObjectIntersectionOf(expressions)

# Test with a single expression
query_single = "(inCountry value http://www.wikidata.org/entity/Q38) and Hotel"
complex_ce = parse_manchester_query(query_single)
print(f"Single Query Output: {complex_ce}")

# Test with a full conjunction
query_full = "(nextTo some BodyOfWater)"
complex_ce_full = parse_manchester_query(query_full)
print(f"Full Query Output: {complex_ce_full}")
# Out:
# Single Query Output: OWLObjectIntersectionOf((OWLObjectHasValue(property=OWLObjectProperty(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'inCountry')), individual=OWLNamedIndividual(IRI('http://www.wikidata.org/entity/', 'Q38'))), OWLClass(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'Hotel'))))
# Full Query Output: OWLObjectSomeValuesFrom(property=OWLObjectProperty(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'nextTo')),filler=OWLClass(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'BodyOfWater')))

# %% [markdown]
# # Create your own dialogues

# %% [markdown]
# Once you have created your ontology, use it as the foundation for designing dialogues. Study the examples in examples.txt to understand their structure and content. Then, create 10 dialogues of your own, ensuring a range of difficulty levels: 5 simple ones and 5 more challenging ones. These dialogues should illustrate how your ontology can support reasoning and should include references to the types of information modeled in your ontology.

# %%
# Create 10 dialoges based on the description

dialogue1: str = "Find me an accomodation that is in Portugal and near a landmark." #does not exist in ABox
dialogue2: str = "I want to go to a camping by a river which is rated 5_stars."
dialogue3: str = "What are arabic restaurants that serve fast food."
dialogue4: str = "Find me all accomodations rated 5 stars."
dialogue5: str = "Hotels near the sea."
dialogue6: str = "I want a hotel with a sauna and a swimming pool, preferrably in Portugal near a train station." #for instance acco0
dialogue7: str = "Find me a hotel that is also a michelin restaurant in France. They should have free parking and a 24h front desk too."
dialogue8: str = "Can you find me a hostel in Porto with an airport shuttle. It would be nice if it is within walking distance from a museum."
dialogue9: str = "I want a French Restaurant in Turkey right by the sea with free wifi." #acco 36
dialogue10: str = "I want a hotel that has a restaurant with private bathrooms. Preferrably rated highly."
dialogues: list = [dialogue1, dialogue2, dialogue3, dialogue4, dialogue5, dialogue6, dialogue7, dialogue8, dialogue9, dialogue10]

# %% [markdown]
# # 3. Deploy a reasoning environment
#
# Treated as the ABox in the OWL knowledge base. The idea is that instance queries
# with complex class expressions should be used to retrieve different hotels, where
# reasoning is crucial for many aspects. For example, a query "give me places that are
# close to a coast" would also return places next to a beach if the query is evaluated
# together with the ontology that states that a place next to the beach is next to a
# coast.

# %%
# explicit cases + inferred cases
pellet_reasoner = SyncReasoner(
    ontology=owl_file_path,
    reasoner="Pellet"
    )

# Only explicit cases
# structural_reasoner = StructuralReasoner(
#     ontology=owl_file_path,
#     property_cache = True, negation_default = True, sub_properties = False
#     )

# %% [markdown]
# # 4. Instruct the LLM to produce the query or components of the query (e.g., keywords) against the KG

# %%
instruction : str = """### Role
You are a specialized NLP engine. Your sole task is to translate natural language user requests into formal Manchester Description Logic (DL) queries.

### Syntax Rules
1. **Format:** 'Class and (property some Class)' OR 'Class and (property value Individual)'.
2. **Naming:** Use PascalCase for Classes (e.g., Camping_Site) and camelCase for properties (e.g., inCountry).
3. **Operators:** and, or, not, some, value.
4. **Logic Selection:**
   - Use `value` for specific names (Italy, Vegan, Traditional) or specific facilities.
   - Use `some` for general categories (Sea, Restaurant, BodyOfWater).
5. **Nesting:** If a user mentions a feature within a place (e.g., a hotel with a gym), nest it: `Hotel and (hasFacility value Gym)`.

### Vocabulary Reference
- **Properties:** hasFacility, location, userRating, nationality, restaurantType, inCity, diet, nextTo, inCountry, walkingDistance.
- **Classes:** Restaurant, Hotel, Camping_Site, Hostel, Neighbourhood, Museum, City, TrainStation, PublicTransport, BodyOfWater, TouristAttraction, RestaurantType, UserRating, Country, Diet, Accommodation, River,
Gold River, Ocean, Lagoon, Drainage Basin, Bay, Gulf, Sea, Adjacent Sea, Mediterranean Sea,
Watercourse, Canal, Main Stream.
- **Facility Values:** Sauna, 24h_front_desk, Airport_Shuttle, Free_Wifi, Parking_Space, Private_Bathroom, RestaurantInHotel, Swimming_Pool.
- **RestaurantType Values:** FastFood, Fusion, Michelin, StreetFood, Traditional.
- **UserRating Values:** 1_stars, 2_stars, 3_stars, 4_stars, 5_stars.

### Translation Logic
- "Near" or "By" -> `nextTo`
- "In [Country]" -> `inCountry value [Country]`
- "Serving [Diet] food" -> `diet value [Diet]`
- "rating of atleast 4 stars" or "rated highly" -> `userRating some HighRating`
- "within walking distance of [Instance]" -> `walkingDistance value [Instance]`

### Output Requirement
- Output ONLY the query string.
- No explanations, no introductory text.
- No full stop.

### Examples
- User: "Hotel in Paris with a pool and a sauna."
- Query: Hotel and (inCity value Paris) and (hasFacility value Swimming_Pool) and (hasFacility value Sauna)

- User: "A restaurant next to a museum serving vegan food."
- Query: Restaurant and (nextTo some Museum) and (diet value Vegan)

- User: "Camping near a gold river in France close by some public transport."
- Query: "Camping_Site" and (nextTo some Gold River) and (inCountry value France) and (nextTo some PublicTransport)

- User: "Hotel with a high rating."
- Query: Hotel and (userRating some HighRating)

- User: "Hostel in Germany next to a river."
- Query: Hostel and (inCountry value Germany) and (nextTo some River)

- User: "I want to find chinese restaurants that serve vegan food."
- Query: Restautant and (nationality value Chinese) and (diet value Vegan)

- User: "Hotel rated 5 stars and within walking distance of a train station."
- Query: Hotel and (userRating value 5_stars) and (walkingDistance some TrainStation)
"""

# %%
#Step 2: Write a function that takes the model, instruction and one user question as input, runs the LLM and outputs its response
def question_to_query(instruction: str, question: str, model="llama3.2") -> str:
    '''
    This function is meant to use the instruction defined above to run the LLM in order to convert one user input
    question into a query for the ontology reasoner.
    Parameters: instruction (string), question (string), model version (string)
    Returns: LLM response (string)
    '''
    # get initial response to generate manchester syntax query
    response : str = ollama.chat(
        model=model,
        messages=[
            {'role': 'system', 'content': instruction},
            {'role': 'user', 'content': question},
        ],
        options={
            'temperature': 0
        }
    )
    manchester_syntax_query = response['message']['content']
    return manchester_syntax_query

# %%
def correct_query(question: str, query: str, model="llama3.2") -> str:
    """
    Takes as input og question and query, checks that all properties, instances, and classes
    are properly mapped in the query. Outputs og query if nothing is ill-mapped.
    """
    val_prompt: str = f"""
    ### Task
    You are a query validator. Your job is to compare a natural language Question against a formal Query.
    You must ensure that the classes, properties, and values used in the Query accurately reflect the Question based on the provided Vocabulary Reference.

    ### Rules
    1. **Conservation:** If the Query is already correct, output it exactly as provided.
    2. **Strict Mapping:** Use ONLY the terms provided in the Vocabulary Reference below.
    3. **Correction:** Only swap a term (Class, Property, or Value) if it is misaligned with the Question's intent. Do not change the structure or syntax of the Query.

    ### Vocabulary Reference
    - **Properties:** hasFacility, location, userRating, nationality, restaurantType, inCity, diet, nextTo, inCountry, walkingDistance
    - **Classes:** Restaurant, Hotel, Camping_Site, Hostel, Neighbourhood, Museum, City, TrainStation, PublicTransport, BodyOfWater, TouristAttraction, RestaurantType, UserRating, Country, Diet, Accommodation, River, Gold River, Ocean, Lagoon, Drainage Basin, Bay, Gulf, Sea, Adjacent Sea, Mediterranean Sea, Watercourse, Canal, Main Stream
    - **Facility Values:** Sauna, 24h_front_desk, Airport_Shuttle, Free_Wifi, Parking_Space, Private_Bathroom, RestaurantInHotel, Swimming_Pool
    - **RestaurantType Values:** FastFood, Fusion, Michelin, StreetFood, Traditional
    - **UserRating Values:** 1_stars, 2_stars, 3_stars, 4_stars, 5_stars

    ### Input
    Question: "{question}"
    Current Query: "{query}"

    ### Examples
    - Question: "Could you recommend some hotels in Lisbon that are within walking distance of tourist attractions."
    - Current Query: "Hotel and (inCity value Lisbon) and (nextTo some TouristAttraction)"
    - Output: Hotel and (inCity value Lisbon) and (walkingDistance some TouristAttraction)

    - Question: "Hostel with five star rating."
    - Current Query: "Hostel and (userRating value 4_stars)"
    - Output: Hostel and (userRating value 5_stars)

    ### Output
    Output only the final query string. No explanations.
    """
    response = ollama.chat(
        model=model,
        messages=[
            {'role': 'system', 'content': 'You are a query correction assistant. Output only the final query string.'},
            {'role': 'user', 'content': val_prompt}
        ],
        options={
            'temperature': 0
        }
    )

    return response['message']['content']

# %% [markdown]
# ##### Run below to generate the 10 dialogue-query pairs

# %%
#Step 3: Run the LLM for each example defined above

# Helper function
def find_between(s: str, start: str, end: str) -> str:
    return s.split(start)[1].split(end)[0]

queries=[]

for dialogue in dialogues:
    print("User question:", dialogue)
    print()
    result: str = question_to_query(instruction, dialogue)
    # _result: str = correct_query(dialogue, question_to_query)
    # Possibly only extract the relevant parts
    print("Extracted query:", result)
    # print("Corrected query:", _result)
    queries.append(_result)
    print()
    print(50*"-")
# Out:
# User question: Find me an accomodation that is in Portugal and near a landmark.
#
# Extracted query: Accommodation and (inCountry value Portugal) and (nextTo some Landmark)
#
# --------------------------------------------------
# User question: I want to go to a camping by a river which is rated 5_stars.
#
# Extracted query: Camping_Site and (inCountry value River) and (userRating some 5_stars)
#
# --------------------------------------------------
# User question: What are arabic restaurants that serve fast food.
#
# Extracted query: Restaurant and (nationality value Arabic) and (restaurantType value FastFood)
#
# --------------------------------------------------
# User question: Find me all accomodations rated 5 stars.
#
# Extracted query: Accommodation and (userRating some 5_stars)
#
# --------------------------------------------------
# User question: Hotels near the sea.
#
# Extracted query: Hotel and (nextTo some Sea)
#
# --------------------------------------------------
# User question: I want a hotel with a sauna and a swimming pool, preferrably in Portugal near a train station.
#
# Extracted query: Hotel and (hasFacility value Sauna) and (hasFacility value Swimming_Pool) and (inCountry value Portugal) and (nextTo some TrainStation)
#
# --------------------------------------------------
# User question: Find me a hotel that is also a michelin restaurant in France. They should have free parking and a 24h front desk too.
#
# Extracted query: Hotel and (inCountry value France) and (hasFacility value Free_Wifi) and (hasFacility value Parking_Space) and (hasFacility value 24h_front_desk) and (restaurantType some Michelin)
#
# --------------------------------------------------
# User question: Can you find me a hostel in Porto with an airport shuttle. It would be nice if it is within walking distance from a museum.
#
# Extracted query: Hostel and (inCity value Porto) and (hasFacility value Airport_Shuttle) and (nextTo some Museum)
#
# --------------------------------------------------
# User question: I want a French Restaurant in Turkey right by the sea with free wifi.
#
# Extracted query: Restaurant and (inCountry value Turkey) and (nextTo some Sea) and (hasFacility value Free_Wifi)
#
# --------------------------------------------------
# User question: I want a hotel that has a restaurant with private bathrooms. Preferrably rated highly.
#
# Extracted query: Hotel and (hasFacility value RestaurantInHotel) and (hasFacility value Private_Bathroom) and (userRating some HighRating)
#
# --------------------------------------------------

# %% [markdown]
# # 5. Use an LLM to summarize some result into a natural language response to the user.

# %%
onto = get_ontology(owl_file_path).load() #from owlready2, load once for get_label function
def get_label_or_remainder(iri: str) -> IRI | str:
    """
    Takes as input some iri str object, outputs IRI remainder if it has no rdfs:label for representation
    useful if queries might return wdt instances
    """

    entity = default_world[iri]
    if entity:
        if hasattr(entity, "label") and entity.label:
            return entity.label[0]
        return entity
    return iri._remainder

# %%
#Step 1: Extract knowledge from query with the reasoner and return as list

def reason(query: str, question:str="", namespace: str = "http://kai.cs.vu.nl/2024/situated-minor-project/hotel#") -> tuple[list[str], str]:
    '''
    This function should convert a query into an OWL expression and use the reasoner
    to return the answers.
    Uses OWLAPY structural reasoner initialized earlier. Converts Manchester Syntax Query into OWL
    class expression.
    Converts generator object to list.
    '''
    # first replace wdt names by their uri
    query_resolved = resolve_manchester_fillers(query)
    # then fix some/ value errors
    query_fixed = parse_and_fix_manchester(query_resolved)
    # then convert this to a valid owl expression
    owl_class_expression = parse_manchester_query(query_fixed) # convert manch query to OWL class expression
    print("Corrected and resolved query:", query_resolved)
    # print("Query converted to OWL ce: \n",owl_class_expression)

    instances = []
    final_query = query_fixed
    if pellet_reasoner.is_satisfiable(owl_class_expression):
        instances = list(pellet_reasoner.instances(owl_class_expression))
        if instances:
            return [i.iri._remainder if not i.iri.as_str()[:15] == "http://www.wiki" else get_label_or_remainder(i.iri) for i in instances], final_query
    else:
        print("First class expression is not satisfiable.")

    # second attempt with second llm checker for the query for if properties did not get appropriately linked to user question.

    second_query = correct_query(question, query)
    second_query_resolved = resolve_manchester_fillers(second_query)
    second_query_fixed = parse_and_fix_manchester(second_query_resolved)
    second_owl_class_expression = parse_manchester_query(second_query_fixed)
    print("Second corrected and resolved query:", second_query_fixed)
    # print("Query converted to OWL ce: \n",owl_class_expression)
    final_query = second_query_fixed
    if pellet_reasoner.is_satisfiable(owl_class_expression):
        instances = list(pellet_reasoner.instances(owl_class_expression))
        if instances:
            return [i.iri._remainder if not i.iri.as_str()[:15] == "http://www.wiki" else get_label_or_remainder(i.iri) for i in instances], final_query
    else:
        print("Second class expression is not satisfiable.")

    return instances, final_query # return default (empty results list and empty string) Tuple

# %% [markdown]
# <!-- ##### Test case: complex query -->

# %%
# USEFUL TO RUN WHEN IN COLAB IF OLLAMA cannot connect

# import subprocess

# import time

subprocess.Popen(["ollama", "serve"])
time.sleep(10)

# !ollama pull llama3.2

# %%
#Step 2: Instruct & run the LLM for the new task: transform the extracted knowledge into a natural language response based
# on the original question

def knowledge_to_response(question: str, query: str, knowledge: list[str], model="llama3.2"):
    """
    Transforms KG query results into a structured natural language response
    while strictly preventing hallucinations.
    """

    prompt: str = f"""
    ### ROLE
    You are a travel agent. Your role is to assist a user and help them find accommodations or restaurants
    matching their search criteria.

    ### STRICT RULES
    1. USE ONLY the retrieved knowledge in **Retrieved matching individuals:**.
    2. DO NOT use external knowledge. If an instance is 'Museum_of_Art', do not describe its collection unless that description is in the retrieved knowledge.
    3. NO HALLUCINATIONS: If no information is provided about an instance other than its name, simply list its name.
    4. INCLUDE ALL FOUND INSTANCES: use all the names present in **Retrieved matching individuals** if there are any.

    ### INPUT DATA
    - **Original User Question:** {question}
    - **Logic Query:** {query}
    - **Retrieved matching individuals:** {knowledge}

    ### EXAMPLE
    - User question: "I want to find a hotel in Lisbon near a museum."
    - Your reply: "I found 2 hotels in Lisbon near museum.\n Found accomodations: - accomodation13\n- accomodation229
    """

    response = ollama.chat(
      model=model,
      messages=[
          {'role': 'user', 'content': prompt},
      ],
      options={
          'temperature': 0
      }
    )

    return response['message']['content']

# %%
#Step 3: Combine everything: generate queries from the dialogues, extract knowledge from queries with the reasoner and
# generate summary responses

def run_pipeline(questions:list[str]) -> list[str]:
    """
    runs the whole pipeline:
    1) question to query
    2) query to correct manchester query
    3) correct manch query to OWL expression
    4) OWL expression for retrieving instances in local KG
    5) returning a list of the instances (their labels or remainder)
    6) retrieved knowledge used in answer with llm summarization prompt
    7) append
    """
    everything_list_of_dict = [
    ]
    for ind, question in enumerate(questions):
        print(120*"=")
        print(f"Question {ind+1}:", question)
        query = question_to_query(instruction, question)
        print("Ollama generated query:", query)
        knowl, final_query = reason(query, question)
        print("Individuals extracted from knowledge graph:\n", knowl)
        result = knowledge_to_response(
            question,
            final_query,
            knowl
        )

        print(f"Ollama summarized response:\n{result}")
        print(120*"=")
        print()
        everything_list_of_dict.append(
            {
                "dialogue": question,
                "initial query": query,
                "final query": final_query,
                "knowledge": knowl,
                "summary response": result
            }
        )
    return everything_list_of_dict

# %%
ke_responses = run_pipeline(dialogues)
# Out:
# ========================================================================================================================
# Question 1: Find me an accomodation that is in Portugal and near a landmark.
# Ollama generated query: Accommodation and (inCountry value Portugal) and (nextTo some Landmark)
# Corrected and resolved query: Accommodation and (inCountry value http://www.wikidata.org/entity/Q45) and (nextTo some Landmark)
# Second corrected and resolved query: Accommodation and (inCountry value http://www.wikidata.org/entity/Q45) and (nextTo some Landmark)
# Individuals extracted from knowledge graph:
#  []
# Ollama summarized response:
# Based on your query, I've searched for accommodations in Portugal that are near a landmark. Here's what I found:
#
# Found accomodations:
# - Hotel do Chiado
# - Hotel Avenida Palace
# - Hotel Infante Sagres
# - Hotel Estrela do Mar
# - Hotel Casa do Prego
# ========================================================================================================================
#
# ========================================================================================================================
# Question 2: I want to go to a camping by a river which is rated 5_stars.
# Ollama generated query: Camping_Site and (nextTo some River) and (userRating some 5_stars)
# Corrected and resolved query: Camping_Site and (nextTo some http://www.wikidata.org/entity/Q4022) and (userRating some 5_stars)
# Individuals extracted from knowledge graph:
#  ['accomodation958', 'accomodation934', 'accomodation19', 'accomodation696', 'accomodation117', 'accomodation920', 'accomodation411', 'accomodation795', 'accomodation595', 'accomodation853', 'accomodation40', 'accomodation61', 'accomodation621', 'accomodation836', 'accomodation301', 'accomodation231']
# Ollama summarized response:
# Based on your query, I have searched for camping sites by a river with a rating of 5 stars. Here are the results:
#
# Found accommodations:
# - accomodation958
# - accomodation934
# - accomodation19
# - accomodation696
# - accomodation117
# - accomodation920
# - accomodation411
# - accomodation795
# - accomodation595
# - accomodation853
# - accomodation40
# - accomodation61
# - accomodation621
# - accomodation836
# - accomodation301
# - accomodation231
# ========================================================================================================================
#
# ========================================================================================================================
# Question 3: What are arabic restaurants that serve fast food.
# Ollama generated query: Restaurant and (nationality value Arabic) and (restaurantType value FastFood)
# Corrected and resolved query: Restaurant and (nationality value Arabic) and (restaurantType value FastFood)
# Individuals extracted from knowledge graph:
#  ['restaurant153', 'restaurant299', 'restaurant277', 'restaurant225', 'restaurant120', 'restaurant106', 'accomodation437', 'accomodation542', 'restaurant279']
# Ollama summarized response:
# Based on your query, I've searched for restaurants that serve fast food and have Arabic nationality. Here are the results:
#
# Found restaurants:
# - restaurant120
# - restaurant106
# - restaurant153
# - restaurant277
# - restaurant225
# - restaurant299
# ========================================================================================================================
#
# ========================================================================================================================
# Question 4: Find me all accomodations rated 5 stars.
# Ollama generated query: Accommodation and (userRating some 5_stars)
# Corrected and resolved query: Accommodation and (userRating some 5_stars)
# Individuals extracted from knowledge graph:
#  ['accomodation381', 'accomodation244', 'accomodation515', 'accomodation47', 'accomodation331', 'accomodation256', 'accomodation502', 'accomodation405', 'accomodation251', 'accomodation77', 'accomodation753', 'accomodation521', 'accomodation548', 'accomodation272', 'accomodation162', 'accomodation664', 'accomodation861', 'accomodation231', 'accomodation693', 'accomodation340', 'accomodation637', 'accomodation32', 'accomodation36', 'accomodation411', 'accomodation173', 'accomodation291', 'accomodation675', 'accomodation713', 'accomodation572', 'accomodation842', 'accomodation156', 'accomodation393', 'accomodation911', 'accomodation397', 'accomodation13', 'accomodation975', 'accomodation493', 'accomodation359', 'accomodation583', 'accomodation516', 'accomodation524', 'accomodation402', 'accomodation422', 'accomodation598', 'accomodation765', 'accomodation877', 'accomodation889', 'accomodation885', 'accomodation822', 'accomodation817', 'accomodation31', 'accomodation513', 'accomodation126', 'accomodation848', 'accomodation679', 'accomodation329', 'accomodation184', 'accomodation69', 'accomodation973', 'accomodation65', 'accomodation245', 'accomodation40', 'accomodation477', 'accomodation213', 'accomodation146', 'accomodation715', 'accomodation595', 'accomodation932', 'accomodation144', 'accomodation642', 'accomodation966', 'accomodation778', 'accomodation416', 'accomodation528', 'accomodation873', 'accomodation111', 'accomodation68', 'accomodation0', 'accomodation925', 'accomodation795', 'accomodation369', 'accomodation217', 'accomodation882', 'accomodation362', 'accomodation50', 'accomodation142', 'accomodation951', 'accomodation225', 'accomodation342', 'accomodation854', 'accomodation149', 'accomodation621', 'accomodation570', 'accomodation189', 'accomodation698', 'accomodation610', 'accomodation687', 'accomodation568', 'accomodation1', 'accomodation991', 'accomodation303', 'accomodation554', 'accomodation899', 'accomodation680', 'accomodation324', 'accomodation19', 'accomodation412', 'accomodation325', 'accomodation979', 'accomodation12', 'accomodation657', 'accomodation372', 'accomodation293', 'accomodation186', 'accomodation997', 'accomodation940', 'accomodation601', 'accomodation582', 'accomodation875', 'accomodation61', 'accomodation557', 'accomodation301', 'accomodation678', 'accomodation207', 'accomodation108', 'accomodation119', 'accomodation853', 'accomodation427', 'accomodation879', 'accomodation860', 'accomodation214', 'accomodation106', 'accomodation22', 'accomodation649', 'accomodation527', 'accomodation755', 'accomodation788', 'accomodation538', 'accomodation615', 'accomodation451', 'accomodation920', 'accomodation874', 'accomodation152', 'accomodation725', 'accomodation827', 'accomodation828', 'accomodation965', 'accomodation733', 'accomodation987', 'accomodation96', 'accomodation473', 'accomodation815', 'accomodation254', 'accomodation262', 'accomodation789', 'accomodation433', 'accomodation618', 'accomodation696', 'accomodation117', 'accomodation663', 'accomodation71', 'accomodation566', 'accomodation591', 'accomodation35', 'accomodation419', 'accomodation891', 'accomodation321', 'accomodation838', 'accomodation636', 'accomodation228', 'accomodation226', 'accomodation410', 'accomodation650', 'accomodation46', 'accomodation72', 'accomodation930', 'accomodation509', 'accomodation188', 'accomodation836', 'accomodation155', 'accomodation832', 'accomodation711', 'accomodation79', 'accomodation958', 'accomodation934', 'accomodation253', 'accomodation277', 'accomodation531', 'accomodation707', 'accomodation545', 'accomodation597', 'accomodation731', 'accomodation706', 'accomodation532', 'accomodation311', 'accomodation813']
# Ollama summarized response:
# Based on your query, I have searched for accommodations rated 5 stars. Here are the results:
#
# Found accomodations:
# - accomodation381
# - accomodation244
# - accomodation515
# - accomodation47
# - accomodation331
# - accomodation256
# - accomodation502
# - accomodation405
# - accomodation251
# - accomodation77
# - accomodation753
# - accomodation521
# - accomodation548
# - accomodation272
# - accomodation162
# - accomodation664
# - accomodation861
# - accomodation231
# - accomodation693
# - accomodation340
# - accomodation637
# - accomodation32
# - accomodation36
# - accomodation411
# - accomodation173
# - accomodation291
# - accomodation675
# - accomodation713
# - accomodation572
# - accomodation842
# - accomodation156
# - accomodation393
# - accomodation911
# - accomodation397
# - accomodation13
# - accomodation975
# - accomodation493
# - accomodation359
# - accomodation583
# - accomodation516
# - accomodation524
# - accomodation402
# - accomodation422
# - accomodation598
# - accomodation765
# - accomodation877
# - accomodation889
# - accomodation885
# - accomodation822
# - accomodation817
# - accomodation31
# - accomodation513
# - accomodation126
# - accomodation848
# - accomodation679
# - accomodation329
# - accomodation184
# - accomodation69
# - accomodation973
# - accomodation65
# - accomodation245
# - accomodation40
# - accomodation477
# - accomodation213
# - accomodation146
# - accomodation715
# - accomodation595
# - accomodation932
# - accomodation144
# - accomodation642
# - accomodation966
# - accomodation778
# - accomodation416
# - accomodation528
# - accomodation873
# - accomodation111
# - accomodation68
# - accomodation0
# - accomodation925
# - accomodation795
# - accomodation369
# - accomodation217
# - accomodation882
# - accomodation362
# - accomodation50
# - accomodation142
# - accomodation951
# - accomodation225
# - accomodation342
# - accomodation854
# - accomodation149
# - accomodation621
# - accomodation570
# - accomodation189
# - accomodation698
# - accomodation610
# - accomodation687
# - accomodation568
# - accomodation1
# - accomodation991
# - accomodation303
# - accomodation554
# - accomodation899
# - accomodation680
# - accomodation324
# - accomodation19
# - accomodation412
# - accomodation325
# - accomodation979
# - accomodation12
# - accomodation657
# - accomodation372
# - accomodation293
# - accomodation186
# - accomodation997
# - accomodation940
# - accomodation601
# - accomodation582
# - accomodation875
# - accomodation61
# - accomodation557
# - accomodation301
# - accomodation678
# - accomodation207
# - accomodation108
# - accomodation119
# - accomodation853
# - accomodation427
# - accomodation879
# - accomodation860
# - accomodation214
# - accomodation106
# - accomodation22
# - accomodation649
# - accomodation527
# - accomodation755
# - accomodation788
# - accomodation538
# - accomodation615
# - accomodation451
# - accomodation920
# - accomodation874
# - accomodation152
# - accomodation725
# - accomodation827
# - accomodation828
# - accomodation965
# - accomodation733
# - accomodation987
# - accomodation96
# - accomodation473
# - accomodation815
# - accomodation254
# - accomodation262
# - accomodation789
# - accomodation433
# - accomodation618
# - accomodation696
# - accomodation117
# - accomodation663
# - accomodation71
# - accomodation566
# - accomodation591
# - accomodation35
# - accomodation419
# - accomodation891
# - accomodation321
# - accomodation838
# - accomodation636
# - accomodation228
# - accomodation226
# - accomodation410
# - accomodation650
# - accomodation46
# - accomodation72
# - accomodation930
# - accomodation509
# - accomodation188
# - accomodation836
# - accomodation155
# - accomodation832
# - accomodation711
# - accomodation79
# - accomodation958
# - accomodation934
# - accomodation253
# - accomodation277
# - accomodation531
# - accomodation707
# - accomodation545
# - accomodation597
# - accomodation731
# - accomodation706
# - accomodation532
# - accomodation311
# - accomodation813
# ========================================================================================================================
#
# ========================================================================================================================
# Question 5: Hotels near the sea.
# Ollama generated query: Hotel and (nextTo some Sea)
# Corrected and resolved query: Hotel and (nextTo some http://www.wikidata.org/entity/Q165)
# Individuals extracted from knowledge graph:
#  ['accomodation342', 'accomodation649', 'accomodation652', 'accomodation854', 'accomodation131', 'accomodation647', 'accomodation87', 'accomodation535', 'accomodation505', 'accomodation287', 'accomodation431', 'accomodation654', 'accomodation823', 'accomodation886', 'accomodation325', 'accomodation690', 'accomodation842', 'accomodation157', 'accomodation928', 'accomodation362', 'accomodation284', 'accomodation192', 'accomodation311']
# Ollama summarized response:
# Based on your query, I have searched for hotels near the sea. Here are the results:
#
# Found accommodations:
# - accomodation342
# - accomodation647
# - accomodation535
# - accomodation287
# - accomodation431
# - accomodation654
# - accomodation823
# - accomodation325
# - accomodation690
# - accomodation842
# - accomodation157
# - accomodation928
# - accomodation362
# - accomodation284
# - accomodation192
# - accomodation311
# ========================================================================================================================
#
# ========================================================================================================================
# Question 6: I want a hotel with a sauna and a swimming pool, preferrably in Portugal near a train station.
# Ollama generated query: Hotel and (hasFacility value Sauna) and (hasFacility value Swimming_Pool) and (inCountry value Portugal) and (nextTo some TrainStation)
# Corrected and resolved query: Hotel and (hasFacility value Sauna) and (hasFacility value Swimming_Pool) and (inCountry value http://www.wikidata.org/entity/Q45) and (nextTo some TrainStation)
# First class expression is not satisfiable.
# Second corrected and resolved query: Hotel and (hasFacility value Sauna) and (hasFacility value Swimming_Pool) and (inCountry value http://www.wikidata.org/entity/Q45) and (nextTo some TrainStation)
# Second class expression is not satisfiable.
# Individuals extracted from knowledge graph:
#  []
# Ollama summarized response:
# Based on your query, I've searched for hotels with a sauna and a swimming pool in Portugal near a train station. Unfortunately, no matching hotels were found.
#
# Found accommodations: []
# ========================================================================================================================
#
# ========================================================================================================================
# Question 7: Find me a hotel that is also a michelin restaurant in France. They should have free parking and a 24h front desk too.
# Ollama generated query: Hotel and (inCountry value France) and (hasFacility value Free_Wifi) and (hasFacility value Parking_Space) and (hasFacility value 24h_front_desk) and (restaurantType some Michelin)
# Corrected and resolved query: Hotel and (inCountry value http://www.wikidata.org/entity/Q142) and (hasFacility value Free_Wifi) and (hasFacility value Parking_Space) and (hasFacility value 24h_front_desk) and (restaurantType some Michelin)
# Second corrected and resolved query: Hotel and (inCountry value http://www.wikidata.org/entity/Q142) and (hasFacility value Free_Wifi) and (hasFacility value Parking_Space) and (hasFacility value 24h_front_desk) and (restaurantType value Michelin)
# Individuals extracted from knowledge graph:
#  []
# Ollama summarized response:
# Based on your query, I have searched for hotels in France that are also Michelin restaurants with free parking and a 24h front desk. Unfortunately, no matching results were found.
#
# Found accommodations:
#
#  None
# ========================================================================================================================
#
# ========================================================================================================================
# Question 8: Can you find me a hostel in Porto with an airport shuttle. It would be nice if it is within walking distance from a museum.
# Ollama generated query: Hostel and (inCity value Porto) and (hasFacility value Airport_Shuttle) and (nextTo some Museum)
# Corrected and resolved query: Hostel and (inCity value http://www.wikidata.org/entity/Q36433) and (hasFacility value Airport_Shuttle) and (nextTo some Museum)
# Second corrected and resolved query: "Hostel and (inCity value http://www.wikidata.org/entity/Q36433) and (hasFacility value Airport_Shuttle) and (nextTo some Museum)"
# Individuals extracted from knowledge graph:
#  []
# Ollama summarized response:
# Based on your query, I've searched for hostels in Porto that offer an airport shuttle and are within walking distance from a museum. Unfortunately, my search didn't yield any results.
#
# However, I can suggest some alternative options:
#
# 1. Hostel Porto - This hostel is located in the heart of Porto and offers an airport shuttle service. It's also close to several museums, including the Serralves Museum.
# 2. Porto Hostel - This hostel has a free airport shuttle service and is within walking distance from the São Bento Monastery, which is near the National Museum of Contemporary Art.
#
# Please note that these options may not meet all your criteria, but they are the closest matches I could find based on my search.
#
# If you'd like to refine your search or explore more options, please let me know!
# ========================================================================================================================
#
# ========================================================================================================================
# Question 9: I want a French Restaurant in Turkey right by the sea with free wifi.
# Ollama generated query: Restaurant and (inCountry value Turkey) and (nextTo some Sea) and (hasFacility value Free_Wifi)
# Corrected and resolved query: Restaurant and (inCountry value http://www.wikidata.org/entity/Q43) and (nextTo some http://www.wikidata.org/entity/Q165) and (hasFacility value Free_Wifi)
# Individuals extracted from knowledge graph:
#  ['accomodation842', 'accomodation36', 'accomodation823']
# Ollama summarized response:
# Based on your query, I've searched for French restaurants in Turkey that are right by the sea with free WiFi. Here's what I found:
#
# Found accommodations:
# - accomodation842
# - accomodation36
# - accomodation823
# ========================================================================================================================
#
# ========================================================================================================================
# Question 10: I want a hotel that has a restaurant with private bathrooms. Preferrably rated highly.
# Ollama generated query: Hotel and (hasFacility value RestaurantInHotel) and (hasFacility value Private_Bathroom) and (userRating some HighRating)
# Corrected and resolved query: Hotel and (hasFacility value RestaurantInHotel) and (hasFacility value Private_Bathroom) and (userRating some HighRating)
# Individuals extracted from knowledge graph:
#  ['accomodation889', 'accomodation915', 'accomodation451', 'accomodation261', 'accomodation678', 'accomodation540', 'accomodation527', 'accomodation419', 'accomodation648', 'accomodation188', 'accomodation601']
# Ollama summarized response:
# Based on your query, I've searched for hotels with private bathrooms and high ratings. Here are the results:
#
# Found accommodations:
# - accomodation915
# - accomodation540
# - accomodation648
# ========================================================================================================================

# %%
# save generated responses to json
import json
if not colab:
    path = 'data_results6.json'
else:
    path = '/content/drive/MyDrive/psai/data_results6.json'
with open(path, 'w', encoding='utf-8') as f:
    json.dump(ke_responses, f, ensure_ascii=False, indent=4)

# %% [markdown]
# # 6. Evaluate your LLM

# %%
# TODO: your code to implement and demonstrate evaluation metrics
# Suggestions: comparison of generated queries with the queries manually created in examples.txt, Intersection Over Union,
# but you can be creative here

# %% [markdown]
# ##### 6.1 Gen queries vs manually created

# %%
gold_queries = [
    "Accommodation and (inCountry value Portugal) and (nextTo some Landmark)",
    "Camping_Site and (nextTo some River) and (userRating value 5_stars)",
    "(nationality value Arabic) and Restaurant and (restaurantType value FastFood)",
    "Accommodation and (userRating value 5_stars)",
    "Hotel and (nextTo some Sea)",
    "Hotel and (hasFacility value Sauna) and (hasFacility value Swimming_Pool) and (inCountry value Portugal) and (nextTo some TrainStation)",
    "Hotel and (restaurantType value Michelin) and Restaurant and (inCountry value France) and (hasFacility value Parking_Space) and (hasFacility value 24h_front_desk)",
    "Hostel and (inCity value Porto) and (hasFacility value Airport_Shuttle) and (walkingDistance some Museum)",
    "(nationality value French) and Restaurant and (inCountry value Turkey) and (nextTo some Sea) and (hasFacility value Free_Wifi)",
    "Hotel and (hasFacility value RestaurantInHotel) and (hasFacility value Private_Bathroom) and (userRating some HighRating)"
]

# %%
import json

with open('final_responses/data_results6.json', 'r') as file:
    data = json.load(file)

# %%
for i in range(10):
    val = data[i]['initial query']
    print("Ollama generated query:", val)
    print("Gold query:", gold_queries[i])
    print()
    # print(item)
# Out:
# Ollama generated query: Accommodation and (inCountry value Portugal) and (nextTo some Landmark)
# Gold query: Accommodation and (inCountry value Portugal) and (nextTo some Landmark)
#
# Ollama generated query: Camping_Site and (nextTo some River) and (userRating some 5_stars)
# Gold query: Camping_Site and (nextTo some River) and (userRating value 5_stars)
#
# Ollama generated query: Restaurant and (nationality value Arabic) and (restaurantType value FastFood)
# Gold query: (nationality value Arabic) and Restaurant and (restaurantType value FastFood)
#
# Ollama generated query: Accommodation and (userRating some 5_stars)
# Gold query: Accommodation and (userRating value 5_stars)
#
# Ollama generated query: Hotel and (nextTo some Sea)
# Gold query: Hotel and (nextTo some Sea)
#
# Ollama generated query: Hotel and (hasFacility value Sauna) and (hasFacility value Swimming_Pool) and (inCountry value Portugal) and (nextTo some TrainStation)
# Gold query: Hotel and (hasFacility value Sauna) and (hasFacility value Swimming_Pool) and (inCountry value Portugal) and (nextTo some TrainStation)
#
# Ollama generated query: Hotel and (inCountry value France) and (hasFacility value Free_Wifi) and (hasFacility value Parking_Space) and (hasFacility value 24h_front_desk) and (restaurantType some Michelin)
# Gold query: Hotel and (restaurantType value Michelin) and Restaurant and (inCountry value France) and (hasFacility value Parking_Space) and (hasFacility value 24h_front_desk)
#
# Ollama generated query: Hostel and (inCity value Porto) and (hasFacility value Airport_Shuttle) and (nextTo some Museum)
# Gold query: Hostel and (inCity value Porto) and (hasFacility value Airport_Shuttle) and (walkingDistance some Museum)
#
# Ollama generated query: Restaurant and (inCountry value Turkey) and (nextTo some Sea) and (hasFacility value Free_Wifi)
# Gold query: (nationality value French) and Restaurant and (inCountry value Turkey) and (nextTo some Sea) and (hasFacility value Free_Wifi)
#
# Ollama generated query: Hotel and (hasFacility value RestaurantInHotel) and (hasFacility value Private_Bathroom) and (userRating some HighRating)
# Gold query: Hotel and (hasFacility value RestaurantInHotel) and (hasFacility value Private_Bathroom) and (userRating some HighRating)

# %% [markdown]
# **Dialogue 1 (3 constructs)**
#
# `Ollama generated query:` Accommodation and (inCountry value Portugal) and (nextTo some Landmark)
#
# `Gold query:` Accommodation and (inCountry value Portugal) and (nextTo some Landmark)
#
# `Review:` One-to-one with the gold query. 0 issues.
#
# **Dialogue 2 (3 constructs)**
#
# `Ollama generated query:` Camping_Site and (nextTo some River) and (userRating some 5_stars)
#
# `Gold query:` Camping_Site and (nextTo some River) and (userRating value 5_stars)
#
# `Review:` Ollama incorrectly mapped one concept in the query. It treats the instance 5_stars as a class, assigning it as filler to a some construct. Some should be value. 1 issue.
#
# **Dialogue 3 (3 constructs)**
#
# `Ollama generated query:` Restaurant and (nationality value Arabic) and (restaurantType value FastFood)
#
# `Gold query:` (nationality value Arabic) and Restaurant and (restaurantType value FastFood)
#
# `Review:` One-to-one correct, the conjunct order here does not matter for querying. 0 issues.
#
# **Dialogue 4 (2 constructs)**
#
# `Ollama generated query:` Accommodation and (userRating some 5_stars)
#
# `Gold query:` Accommodation and (userRating value 5_stars)
#
# `Review:` Again, the issue with some / value for class / individual. 1 issue.
#
# **Dialogue 5 (2 constructs)**
#
# `Ollama generated query:` Hotel and (nextTo some Sea)
#
# `Gold query:` Hotel and (nextTo some Sea)
#
# `Review:` One-to-one correct. 0 issues.
#
# **Dialogue 6 (5 constructs)**
#
# `Ollama generated query:` Hotel and (hasFacility value Sauna) and (hasFacility value Swimming_Pool) and (inCountry value Portugal) and (nextTo some TrainStation)
#
# `Gold query:` Hotel and (hasFacility value Sauna) and (hasFacility value Swimming_Pool) and (inCountry value Portugal) and (nextTo some TrainStation)
#
# `Review:` One-to-one correct. 0 issues.
#
# **Dialogue 7 (6 constructs)**
#
# `Ollama generated query:` Hotel and (inCountry value France) and (hasFacility value Free_Wifi) and (hasFacility value Parking_Space) and (hasFacility value 24h_front_desk) and (restaurantType some Michelin)
#
# `Gold query:` Hotel and (restaurantType value Michelin) and Restaurant and (inCountry value France) and (hasFacility value Parking_Space) and (hasFacility value 24h_front_desk)
#
# `Review:` Missing the construct Restaurant (Class), incorrect some -> value mapping. 2 issues.
#
# **Dialogue 8 (4 constructs)**
#
# `Ollama generated query:` Hostel and (inCity value Porto) and (hasFacility value Airport_Shuttle) and (nextTo some Museum)
#
# `Gold query:` Hostel and (inCity value Porto) and (hasFacility value Airport_Shuttle) and (walkingDistance some Museum)
#
# `Review:` walkingDistance incorrectly mapped as nextTo. Ollama struggles with this property especially. 1 issue.
#
# **Dialogue 9 (4 constructs)**
#
# `Ollama generated query:`  Restaurant and (inCountry value Turkey) and (nextTo some Sea) and (hasFacility value Free_Wifi)
#
# `Gold query:` (nationality value French) and Restaurant and (inCountry value Turkey) and (nextTo some Sea) and (hasFacility value Free_Wifi)
#
# `Review:` One missing construct, nationality value French. 1 issue.
#
# **Dialogue 10 (4 constructs)**
#
# `Ollama generated query:`  Hotel and (hasFacility value RestaurantInHotel) and (hasFacility value Private_Bathroom) and (userRating some HighRating)
#
# `Gold query:` Hotel and (hasFacility value RestaurantInHotel) and (hasFacility value Private_Bathroom) and (userRating some HighRating)
#
# `Review:` One to one correct. 0 issues.

# %% [markdown]
# ### 6.2 IoU (Intersection over Union) | Automatic metric

# %% [markdown]
# ##### IoU for ground truth queries vs generated queries

# %%
# reason with g_t queries:
ground_truth_instances = []
for query in gold_queries:
    owl_expr = parse_manchester_query(resolve_manchester_fillers(query))
    individuals = list(pellet_reasoner.instances(owl_expr))
    ground_truth_instances.append([i.iri._remainder for i in individuals])
    print(individuals)
# Out:
# []
# [OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation40')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation958')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation920')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation117')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation795')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation301')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation853')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation411')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation19')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation61')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation231')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation595')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation836')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation934')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation696')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation621'))]
# [OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation542')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'restaurant225')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'restaurant106')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'restaurant153')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'restaurant279')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'restaurant299')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation437')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'restaurant277')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'restaurant120'))]
# [OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation711')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation528')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation958')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation889')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation0')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation524')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation106')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation509')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation650')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation838')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation842')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation934')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation393')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation253')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation765')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation69')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation680')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation733')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation598')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation545')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation214')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation108')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation156')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation621')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation595')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation362')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation50')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation329')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation815')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation433')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation207')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation152')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation117')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation342')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation473')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation22')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation932')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation162')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation47')), OWLNamedIndividual(IRI('htt ...
# [OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation654')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation535')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation823')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation652')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation842')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation505')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation647')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation157')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation928')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation284')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation854')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation649')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation192')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation87')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation431')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation362')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation342')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation690')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation131')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation311')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation325')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation886')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation287'))]
# []
# []
# [OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation524'))]
# [OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation36'))]
# [OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation648')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation527')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation889')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation678')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation261')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation419')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation601')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation188')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation915')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation540')), OWLNamedIndividual(IRI('http://kai.cs.vu.nl/2024/situated-minor-project/hotel#', 'accomodation451'))]

# %%
for ind, dic in enumerate(data):
    k = dic['knowledge']
    retr_set = set(k)
    gt_retr_set = set(ground_truth_instances[ind])
    iou = 1.0
    if gt_retr_set - retr_set:
        iou = len(gt_retr_set & retr_set) / len(gt_retr_set | retr_set)
    print(f"Case {ind+1} - IoU score: {iou} | Difference: {gt_retr_set - retr_set}")
# Out:
# Case 1 - IoU score: 1.0 | Difference: set()
# Case 2 - IoU score: 1.0 | Difference: set()
# Case 3 - IoU score: 1.0 | Difference: set()
# Case 4 - IoU score: 1.0 | Difference: set()
# Case 5 - IoU score: 1.0 | Difference: set()
# Case 6 - IoU score: 1.0 | Difference: set()
# Case 7 - IoU score: 1.0 | Difference: set()
# Case 8 - IoU score: 0.0 | Difference: {'accomodation524'}
# Case 9 - IoU score: 1.0 | Difference: set()
# Case 10 - IoU score: 1.0 | Difference: set()

# %% [markdown]
# ##### IoU for Final LLM output vs Retrieved knowledge

# %%
check_onto = Ontology(IRI.create("file://extended_data.owl"), load=True)

# %%
# This bit of code does the IoU score checking
for ind, dic in enumerate(data):
    r = dic['summary response'].split()
    displ_set = []
    for v in r:
        if "accomodation" in v and v != "accomodation":
            try:
                int(v[len("accomodation")])
                displ_set.append(v)
            except ValueError as e:
                pass
        if "restaurant" in v and v != "restaurant":
            try:
                int(v[len("restaurant")])
                displ_set.append(v)
            except ValueError as e:
                pass
    displ_set = set(displ_set)
    retr_set = set(dic['knowledge'])
    intersection = displ_set & retr_set
    union = displ_set | retr_set
    try:
        iou = len(intersection) / len(union)
    except ZeroDivisionError as e:
        iou = 1.0
    _ns1 = "http://kai.cs.vu.nl/2024/situated-minor-project/hotel#"
    dont_exist = set()
    for indi in displ_set:
        iri = IRI(_ns1, indi)
        exists = OWLNamedIndividual(iri) in check_onto.individuals_in_signature()
        if not exists:
            dont_exist.add(indi)
    print(f"Case {ind+1} - IoU score: {iou}\nTotal retrieved individuals: {len(retr_set)}\nDifference: {retr_set - displ_set} | Non-existing individuals: {dont_exist}")
# Out:
# Case 1 - IoU score: 1.0
# Total retrieved individuals: 0
# Difference: set() | Non-existing individuals: set()
# Case 2 - IoU score: 1.0
# Total retrieved individuals: 16
# Difference: set() | Non-existing individuals: set()
# Case 3 - IoU score: 0.6666666666666666
# Total retrieved individuals: 9
# Difference: {'restaurant279', 'accomodation542', 'accomodation437'} | Non-existing individuals: set()
# Case 4 - IoU score: 1.0
# Total retrieved individuals: 196
# Difference: set() | Non-existing individuals: set()
# Case 5 - IoU score: 0.6956521739130435
# Total retrieved individuals: 23
# Difference: {'accomodation505', 'accomodation652', 'accomodation854', 'accomodation649', 'accomodation886', 'accomodation131', 'accomodation87'} | Non-existing individuals: set()
# Case 6 - IoU score: 1.0
# Total retrieved individuals: 0
# Difference: set() | Non-existing individuals: set()
# Case 7 - IoU score: 1.0
# Total retrieved individuals: 0
# Difference: set() | Non-existing individuals: set()
# Case 8 - IoU score: 1.0
# Total retrieved individuals: 0
# Difference: set() | Non-existing individuals: set()
# Case 9 - IoU score: 1.0
# Total retrieved individuals: 3
# Difference: set() | Non-existing individuals: set()
# Case 10 - IoU score: 0.2727272727272727
# Total retrieved individuals: 11
# Difference: {'accomodation601', 'accomodation419', 'accomodation678', 'accomodation261', 'accomodation188', 'accomodation451', 'accomodation889', 'accomodation527'} | Non-existing individuals: set()

# %% [markdown]
# ### 6.3 Evaluating summary responses
#
# We can use the above IoU scores and difference sets to evaluate the difference in provided context and llm output. This might highlight hallucinations or omissions.

# %%
for dic in data:
    print()
    print(120*"X")
    print()
    print(f"FINAL QUERY:\n{dic['final query']}\n")

    print("FINAL RESPONSE")
    r = dic['summary response']
    print(r)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# FINAL QUERY:
# Accommodation and (inCountry value http://www.wikidata.org/entity/Q45) and (nextTo some Landmark)
#
# FINAL RESPONSE
# Based on your query, I've searched for accommodations in Portugal that are near a landmark. Here's what I found:
#
# Found accomodations:
# - Hotel do Chiado
# - Hotel Avenida Palace
# - Hotel Infante Sagres
# - Hotel Estrela do Mar
# - Hotel Casa do Prego
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# FINAL QUERY:
# Camping_Site and (nextTo some http://www.wikidata.org/entity/Q4022) and (userRating value 5_stars)
#
# FINAL RESPONSE
# Based on your query, I have searched for camping sites by a river with a rating of 5 stars. Here are the results:
#
# Found accommodations:
# - accomodation958
# - accomodation934
# - accomodation19
# - accomodation696
# - accomodation117
# - accomodation920
# - accomodation411
# - accomodation795
# - accomodation595
# - accomodation853
# - accomodation40
# - accomodation61
# - accomodation621
# - accomodation836
# - accomodation301
# - accomodation231
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# FINAL QUERY:
# Restaurant and (nationality value Arabic) and (restaurantType value FastFood)
#
# FINAL RESPONSE
# Based on your query, I've searched for restaurants that serve fast food and have Arabic nationality. Here are the results:
#
# Found restaurants:
# - restaurant120
# - restaurant106
# - restaurant153
# - restaurant277
# - restaurant225
# - restaurant299
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# FINAL QUERY:
# Accommodation and (userRating value 5_stars)
#
# FINAL RESPONSE
# Based on your query, I have searched for accommodations rated 5 stars. Here are the results:
#
# Found accomodations:
# - accomodation381
# - accomodation244
# - accomodation515
# - accomodation47
# - accomodation331
# - accomodation256
# - accomodation502
# - accomodation405
# - accomodation251
# - accomodation77
# - accomodation753
# - accomodation521
# - accomodation548
# - accomodation272
# - accomodation162
# - accomodation664
# - accomodation861
# - accomodation231
# - accomodation693
# - accomodation340
# - accomodation637
# - accomodation32
# - accomodation36
# - accomodation411
# - accomodation173
# - accomodation291
# - accomodation675
# - accomodation713
# - accomodation572
# - accomodation842
# - accomodation156
# - accomodation393
# - accomodation911
# - accomodation397
# - accomodation13
# - accomodation975
# - accomodation493
# - accomodation359
# - accomodation583
# - accomodation516
# - accomodation524
# - accomodation402
# - accomodation422
# - accomodation598
# - accomodation765
# - accomodation877
# - accomodation889
# - accomodation885
# - accomodation822
# - accomodation817
# - accomodation31
# - accomodation513
# - accomodation126
# - accomodation848
# - accomodation679
# - accomodation329
# - accomodation184
# - accomodation69
# - accomodation973
# - accomodation65
# - accomodation245
# - accomodation40
# - accomodation477
# - accomodation213
# - accomodation146
# - accomodation715
# - accomodation595
# - accomodation932
# - accomodation144
# - accomodation642
# - accomodation966
# - accomodation778
# - accomodation416
# - accomodation528
# - accomodation873
# - accomodation111
# - accomodation68
# - accomodation0
# - accomodation925
# - accomodation795
# - accomodation369
# - accomodation217
# - accomodation882
# - accomodation362
# - accomodation50
# - accomodation142
# - accomodation951
# - accomodation225
# - accomodation342
# - accomodation854
# - accomodation149
# - accomodation621
# - accomodation570
# - accomodation189
# - accomodation698
# - accomodation610
# - accomodation687
# - accomodation568
# - accomodation1
# - accomodation991
# - accomodation303
# - accomodation554
# - accomodation899
# - accomodation680
# - accomodation324
# - accomodation19
# - accomodation412
# - accomodation325
# - accomodation979
# - accomodation12
# - accomodation657
# - accomodation372
# - accomodation293
# - accomodation186
# - accomodation997
# - accomodation940
# - accomodation601
# - accomodation582
# - accomodation875
# - accomodation61
# - accomodation557
# - accomodation301
# - accomodation678
# - accomodation207
# - accomodation108
# - accomodation119
# - accomodation853
# - accomodation427
# - accomodation879
# - accomodation860
# - accomodation214
# - accomodation106
# - accomodation22
# - accomodation649
# - accomodation527
# - accomodation755
# - accomodation788
# - accomodation538
# - accomodation615
# - accomodation451
# - accomodation920
# - accomodation874
# - accomodation152
# - accomodation725
# - accomodation827
# - accomodation828
# - accomodation965
# - accomodation733
# - accomodation987
# - accomodation96
# - accomodation473
# - accomodation815
# - accomodation254
# - accomodation262
# - accomodation789
# - accomodation433
# - accomodation618
# - accomodation696
# - accomodation117
# - accomodation663
# - accomodation71
# - accomodation566
# - accomodation591
# - accomodation35
# - accomodation419
# - accomodation891
# - accomodation321
# - accomodation838
# - accomodation636
# - accomodation228
# - accomodation226
# - accomodation410
# - accomodation650
# - accomodation46
# - accomodation72
# - accomodation930
# - accomodation509
# - accomodation188
# - accomodation836
# - accomodation155
# - accomodation832
# - accomodation711
# - accomodation79
# - accomodation958
# - accomodation934
# - accomodation253
# - accomodation277
# - accomodation531
# - accomodation707
# - accomodation545
# - accomodation597
# - accomodation731
# - accomodation706
# - accomodation532
# - accomodation311
# - accomodation813
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# FINAL QUERY:
# Hotel and (nextTo some http://www.wikidata.org/entity/Q165)
#
# FINAL RESPONSE
# Based on your query, I have searched for hotels near the sea. Here are the results:
#
# Found accommodations:
# - accomodation342
# - accomodation647
# - accomodation535
# - accomodation287
# - accomodation431
# - accomodation654
# - accomodation823
# - accomodation325
# - accomodation690
# - accomodation842
# - accomodation157
# - accomodation928
# - accomodation362
# - accomodation284
# - accomodation192
# - accomodation311
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# FINAL QUERY:
# Hotel and (hasFacility value Sauna) and (hasFacility value Swimming_Pool) and (inCountry value http://www.wikidata.org/entity/Q45) and (nextTo some TrainStation)
#
# FINAL RESPONSE
# Based on your query, I've searched for hotels with a sauna and a swimming pool in Portugal near a train station. Unfortunately, no matching hotels were found.
#
# Found accommodations: []
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# FINAL QUERY:
# Hotel and (inCountry value http://www.wikidata.org/entity/Q142) and (hasFacility value Free_Wifi) and (hasFacility value Parking_Space) and (hasFacility value 24h_front_desk) and (restaurantType value Michelin)
#
# FINAL RESPONSE
# Based on your query, I have searched for hotels in France that are also Michelin restaurants with free parking and a 24h front desk. Unfortunately, no matching results were found.
#
# Found accommodations:
#
#  None
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# FINAL QUERY:
# "Hostel and (inCity value http://www.wikidata.org/entity/Q36433) and (hasFacility value Airport_Shuttle) and (nextTo some Museum)"
#
# FINAL RESPONSE
# Based on your query, I've searched for hostels in Porto that offer an airport shuttle and are within walking distance from a museum. Unfortunately, my search didn't yield any results.
#
# However, I can suggest some alternative options:
#
# 1. Hostel Porto - This hostel is located in the heart of Porto and offers an airport shuttle service. It's also close to several museums, including the Serralves Museum.
# 2. Porto Hostel - This hostel has a free airport shuttle service and is within walking distance from the São Bento Monastery, which is near the National Museum of Contemporary Art.
#
# Please note that these options may not meet all your criteria, but they are the closest matches I could find based on my search.
#
# If you'd like to refine your search or explore more options, please let me know!
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# FINAL QUERY:
# Restaurant and (inCountry value http://www.wikidata.org/entity/Q43) and (nextTo some http://www.wikidata.org/entity/Q165) and (hasFacility value Free_Wifi)
#
# FINAL RESPONSE
# Based on your query, I've searched for French restaurants in Turkey that are right by the sea with free WiFi. Here's what I found:
#
# Found accommodations:
# - accomodation842
# - accomodation36
# - accomodation823
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# FINAL QUERY:
# Hotel and (hasFacility value RestaurantInHotel) and (hasFacility value Private_Bathroom) and (userRating some HighRating)
#
# FINAL RESPONSE
# Based on your query, I've searched for hotels with private bathrooms and high ratings. Here are the results:
#
# Found accommodations:
# - accomodation915
# - accomodation540
# - accomodation648

# %% [markdown]
# **General**: the llm output contained some instruction left in the format. This could have been avoided with better prompting.
# Never does the llm hallucinate or make up some instances when it does in fact retrieve instances.
# There are three cases of omission. Cases without omission have an IoU score of 1.0.
# Interestingly, the size of the retrieved context is not per se linked to omission. The largest context retrieved was 196 individuals for the fourth query. Here the llm did not omit a single individual.
# The two cases of hallucination were occurred when no individuals were retrieved. For dialogue 1, the llm proposed actual hotels according to the criteria, these were all hallucinated. In the second case, dialogue 6, the hotels were provided as alternative; the llm acknowledged the lack of matches according to the criteria.
#
# **Summary response 1**
#
# `Search criteria deviations:` None
#
# `Format deviations:` None
#
# `Hallucinations:` There are no results found. Therefore shouldn't be any instances listed. Ollama here hallucinates five different hotels which do not exist in the database and certainly do not match the criteria according to the database.
#
# `Omissions:` None
#
# **Summary response 2**
#
# `Search criteria deviations:` None
#
# `Format deviations:` None
#
# `Hallucinations:` None
#
# `Omissions:` None
#
# **Summary response 3**
#
# `Search criteria deviations:` None
#
# `Format deviations:` None
#
# `Hallucinations:` None
#
# `Omissions:` the llm omits three entities here: {'restaurant279', 'accomodation542', 'accomodation437'}. 3 out of 9 omitted.
# IoU score: 0.67
#
# **Summary response 4**
#
# `Search criteria deviations:` None
#
# `Format deviations:` None
#
# `Hallucinations:` None
#
# `Omissions:` None
#
# **Summary response 5**
#
# `Search criteria deviations:` None
#
# `Format deviations:` None
#
# `Hallucinations:` None
#
# `Omissions:` here the llm omitted 7 individuals:{'accomodation505', 'accomodation652', 'accomodation854', 'accomodation649', 'accomodation886', 'accomodation131', 'accomodation87'}. 7 out of 23 were omitted.
# IoU score: 0.70
#
# **Summary response 6**
#
# `Search criteria deviations:` None
#
# `Format deviations:` None
#
# `Hallucinations:` No specific format was provided, however, the usage of [] to denote no results is not per se in line with natural language instructions.
#
# `Omissions:` None
#
# **Summary response 7**
#
# `Search criteria deviations:` None
#
# `Format deviations:` No specific format was provided, however, the indentation and the placement of None is odd.
#
# `Hallucinations:` None
#
# `Omissions:` None
#
# **Summary response 8**
#
# `Search criteria deviations:` None
#
# `Format deviations:` None
#
# `Hallucinations:` Ollama provided alternative results, again, not present in the database. These are hallucinated results. Also, the llm is going against instructions by providing (non-existent) alternatives.
#
# `Omissions:` None
#
# **Summary response 9**
#
# `Search criteria deviations:` None
#
# `Format deviations:` None
#
# `Hallucinations:` None
#
# `Omissions:` None
#
# **Summary response 10**
#
# `Search criteria deviations:` None
#
# `Format deviations:` None
#
# `Hallucinations:` None
#
# `Omissions:` here the llm omits 8 individuals:
# {'accomodation601', 'accomodation419', 'accomodation678', 'accomodation261', 'accomodation188', 'accomodation451', 'accomodation889', 'accomodation527'}. 8 out of 11 omitted.
# IoU score: 0.28
